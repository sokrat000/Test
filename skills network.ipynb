# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Elmoataz bellah amr
#
# Data analyst

# %% [markdown]
# I am interested in data science because its realted to every thing in our life now adays it will help me to get pormoted in my current job and ,
#  and it made me understand more about how to take decision .

# %% [markdown]
# this is a simple code explain the sum of two numbers

# %%
1+1
# Out:
# 2

# %% [markdown]
# image ![389-3893194_ibm-watson-logo-transparent-ibm-watson-hd-png.png](attachment:389-3893194_ibm-watson-logo-transparent-ibm-watson-hd-png.png)
#
# [click here to facebook](www.facebook.com)
#
# - one
# - two
# - three
# - four
